# %% [markdown]
# # 2.4
#
# Un experimento implica lanzar un par de dados, uno verde y uno rojo, y registrar los números que resultan. Si x es igual al resultado en el dado verde y y es el resultado en el dado rojo, describa el espacio muestral
#
# - a) Mediante la lista de elementos
# - b) Por medio del método de la regla

# %% [markdown]
# Generaremos la lista con dos bucles anidados

# %%
lista=[]
for i in range(1,7):
    for j in range(1,7):
        lista.append("V"+str(i)+"R"+str(j))
print(*lista, sep='\n,')
# Out:
# V1R1
# ,V1R2
# ,V1R3
# ,V1R4
# ,V1R5
# ,V1R6
# ,V2R1
# ,V2R2
# ,V2R3
# ,V2R4
# ,V2R5
# ,V2R6
# ,V3R1
# ,V3R2
# ,V3R3
# ,V3R4
# ,V3R5
# ,V3R6
# ,V4R1
# ,V4R2
# ,V4R3
# ,V4R4
# ,V4R5
# ,V4R6
# ,V5R1
# ,V5R2
# ,V5R3
# ,V5R4
# ,V5R5
# ,V5R6
# ,V6R1
# ,V6R2
# ,V6R3
# ,V6R4
# ,V6R5
# ,V6R6

# %% [markdown]
# $$S = {\{V1R1
# ,V1R2
# ,V1R3
# ,V1R4
# ,V1R5
# ,V1R6
# ,V2R1
# ,V2R2
# ,V2R3
# ,V2R4
# ,V2R5
# ,V2R6
# ,V3R1
# ,V3R2
# ,V3R3
# ,V3R4
# ,V3R5
# ,V3R6
# ,V4R1
# ,V4R2
# ,V4R3
# ,V4R4
# ,V4R5
# ,V4R6
# ,V5R1
# ,V5R2
# ,V5R3
# ,V5R4
# ,V5R5
# ,V5R6
# ,V6R1
# ,V6R2
# ,V6R3
# ,V6R4
# ,V6R5
# ,V6R6\}}$$

# %% [markdown]
# b) Por el método de la regla tenemos lo siguiente:
#
# $$S = \{(x,y) | \textrm{$x $ es una cara del dado verde y, $y$ es una cara del dado rojo}  \}$$

# %% [markdown]
# # 2.5
#
# Un experimento consiste en lanzar un dado y después lanzar una moneda una vez si el número en el dado es par. Si el número en el dado es impar, la moneda se lanza dos veces. Use la notación 4H, por ejemplo, para denotar el resultado de que el dado muestre 4 y después la moneda caiga en cara, y 3HT para denotar el resultado de que el dado muestre 3, seguido por una cara y después una cruz en la moneda; construya un diagrama de árbol para mostrar los 18 elementos del espacio muestral S.![tree.png](attachment:tree.png)

# %% [markdown]
# # 2.12
#
# a)
#
# ![elements.png](attachment:elements.png)
#
# b) $ A \cup B$
#
# ![union.png](attachment:union.png)
#
# c= $\emptyset$

# %% [markdown]
# # 2.21

# %% [markdown]
# A los participantes de una convención se les ofrecen seis recorridos, cada uno de tres días, a sitios de interés. ¿De cuántas maneras se puede acomodar una persona para que vaya a uno de los recorridos planea- dos por la convención?
#
# Respuesta $n_1 = 6$ visitas turísticas (de un día de duración), $n_2 = 3$ días distintos, entonces $n_1 * n_2 = 18$

# %% [markdown]
# # 2.35
# Un contratista desea construir 9 casas, cada una con diferente diseño. ¿De cuántas formas puede ubicar- las en la calle en la que las va a construir si en un lado de ésta hay 6 lotes y en el lado opuesto hay 3?
#
# $$Respuesta = \frac{9!}{6!3!} = 84$$

# %% [markdown]
# # Obteniendo metadata de las canciones utilizando Spotify APIs

# %% [markdown]
# ## Definimos la función `get_info` que busca canciones en la base de datos de spotify a través del API `v1/search` utilizando nombre de la canción y album por default
#
# ### Al pasar el parámetro `strict=False`, busca solamente por artista. Esto solo se utiliza en el caso del conjunto de datos relativos a 2020, en donde se revisó una por una para ver que fueran las canciones correctas

# %%
import requests, json, logging
import pandas as pd

def get_info(song_name = '', artist_name = '', req_type = 'track',force=False):
    r = requests.post('https://accounts.spotify.com/api/token', headers = {'Authorization': 'Basic NDM0YmFiM2VhNmM2NDg2MmI3NmJkYWUwOTA0NmU2Njg6ZjFlZmFhZmM5MjA1NDFiYzkyZGNlMTk2MzBhZjk1NzE='}, data= {'grant_type': 'client_credentials'})
    token = 'Bearer {}'.format(r.json()['access_token'])
    headers = {'Authorization': token, "Accept": 'application/json', 'Content-Type': "application/json"}
    try:
        payload = {"q" : "artist:{} track:{}".format(artist_name, song_name), "type": req_type, "limit": "1"}
        res = requests.get('https://api.spotify.com/v1/search', params = payload, headers = headers)
        res = res.json()['tracks']['items'][0]
        year = res['album']['release_date'][:4]
        artist_id = res['artists'][0]['id']
        track_id = res['id']
        track_pop = res['popularity'] 
    except:
        print(f'Unable to get {song_name} from {artist_name}')
        if force:
            print(f'Trying {song_name} by only artist {artist_name}')
            payload = {"q" : "artist:{}".format(artist_name, song_name), "type": req_type, "limit": "1"}
            res = requests.get('https://api.spotify.com/v1/search', params = payload, headers = headers)
            res = res.json()['tracks']['items'][0]
            year = res['album']['release_date'][:4]
            artist_id = res['artists'][0]['id']
            track_id = res['id']
            track_pop = res['popularity'] 
        
            
        
    res = requests.get('https://api.spotify.com/v1/audio-analysis/{}'.format(track_id), headers = headers)
    res = res.json()['track']
    
    res2 = requests.get('https://api.spotify.com/v1/audio-features/{}'.format(track_id), headers = headers)
    res2 = res2.json()
    
    duration = res['duration']
    end_fade = res['end_of_fade_in']
    key = res['key']
    key_con = res['key_confidence']
    loud = res['loudness']
    mode = res['mode']
    mode_con = res['mode_confidence']
    start_fade = res['start_of_fade_out']
    temp = res['tempo']
    time_sig = res['time_signature']
    time_sig_con = res['time_signature_confidence']
    danceability=res2['danceability']
    energy=res2['energy']
    key=res2['key']
    loudness=res2['loudness']
    mode=res2['mode']
    speechiness=res2['speechiness']
    acousticness=res2['acousticness']
    instrumentalness=res2['instrumentalness']
    liveness=res2['liveness']
    valence=res2['valence']
    tempo=res2['tempo']
    duration_ms=res2['duration_ms']
    time_signature=res2['time_signature']
    
    res = requests.get('https://api.spotify.com/v1/artists/{}'.format(artist_id), headers = headers)
    artist_hot = res.json()['popularity']/100
    
    return {'duration': duration,
            'key': key,
            'loudness': loud,
            'mode': mode,
            'tempo': temp,
            'artist_hotttnesss': artist_hot,
            'end_of_fade_in': end_fade,
            'start_of_fade_out': start_fade,
            'mode_confidence': mode_con,
            'key_confidence': key_con,
            'time_signature': time_sig,
            'time_signature_confidence': time_sig_con,
            'year': year,
            'popularity': track_pop,
            'danceability':danceability,
            'energy':energy,
            'speechiness':speechiness,
            'acousticness':acousticness,
            'instrumentalness':instrumentalness,
            'liveness':liveness,
            'valence':valence,
            'tempo':tempo,
            'duration_ms':duration_ms,
           }

# %% [markdown]
# ### Bucle para iterar sobre todos los archivos `20*.csv` es decir (2002.csv, 2003.csv...,2019.csv)

# %%
import glob
lista=[]
for filename in glob.iglob('20*.csv'):
    lista.append(pd.read_csv(filename))
    
todos=pd.concat(lista)
todos.reset_index(drop=True,inplace=True)
todos
# Out:
#      Draw          Country                 Artist                   Song  \
# 0       1          Romania   Mădălina and Andrada       Salvați planeta!
# 1       2          Armenia                 Monica       Im Ergi Hnchyune
# 2       3          Belarus  Dasha, Alina & Karyna      Serdtse Belarusi
# 3       4           Russia          Mihail Puntov            Spit angel
# 4       5           Greece        Niki Yiannouchu         Kapoia nychta
# ..    ...              ...                    ...                    ...
# 271    12          Belgium                Lindsay              Mes rêves
# 272    13            Malta       Thea and Friends         Make It Right!
# 273    14           Norway                  Malin  Sommer og skolefri[a]
# 274    15            Spain           Antonio José       Te traigo flores
# 275    16  Belarus Belarus          Ksenia Sitnik             My vmeste
#
#                     Language  Place  Points Language(s)
# 0                   Romanian    9.0    58.0         NaN
# 1                   Armenian    8.0    59.0         NaN
# 2    Russian, Belarusian[22]    6.0    86.0         NaN
# 3                    Russian    7.0    73.0         NaN
# 4                      Greek   14.0    19.0         NaN
# ..                       ...    ...     ...         ...
# 271                   French   10.0    63.0         NaN
# 272                  English   16.0    18.0         NaN
# 273                Norwegian    3.0   123.0         NaN
# 274                  Spanish    2.0   146.0         NaN
# 275                  Russian    1.0   149.0         NaN
#
# [276 rows x 8 columns]

# %% [markdown]
# ### Obtenemos 276 filas, pero terminaremos con muchas menos ya que un conjunto pequeño reducido de canciones se encuentra dentro de la biblioteca de Spotify (lo cual es necesario para llamar a su API y obtener los datos que nos interesan)

# %% [markdown]
# ### Después de llamar a los APIs de Spotify, terminamos con nuestro conjunto de entrenamient

# %%
lista=[]
for index, row in todos.iterrows():
    try:
        dic = get_info(song_name=row["Song"],artist_name=row["Artist"])
        dic['Points']=row['Points']
        dic['Country']=row['Country']
        lista.append(pd.DataFrame(dic,index=[index]))
        
    except Exception as e:
        print(e,f"missing {row['Song']}")
# Out:
# Unable to get Salvați planeta! from Mădălina and Andrada
# local variable 'track_id' referenced before assignment missing Salvați planeta!
# Unable to get Im Ergi Hnchyune from Monica
# local variable 'track_id' referenced before assignment missing Im Ergi Hnchyune
# Unable to get Serdtse Belarusi  from Dasha, Alina & Karyna
# local variable 'track_id' referenced before assignment missing Serdtse Belarusi
# Unable to get Spit angel  from Mihail Puntov
# local variable 'track_id' referenced before assignment missing Spit angel
# Unable to get Kapoia nychta  from Niki Yiannouchu
# local variable 'track_id' referenced before assignment missing Kapoia nychta
# Unable to get Bzz.. from Bzikebi
# local variable 'track_id' referenced before assignment missing Bzz..
# 'track' missing Shut Up
# Unable to get Edna mechta  from Krastyana Krasteva
# local variable 'track_id' referenced before assignment missing Edna mechta
# Unable to get Uvek kad u nebo pogledam  from Maja Mazić
# local variable 'track_id' referenced before assignment missing Uvek kad u nebo pogledam
# Unable to get 1 dag from Marissa
# local variable 'track_id' referenced before assignment missing 1 dag
# Unable to get Matrosy  from Viktoria Petryk
# local variable 'track_id' referenced before assignment missing Matrosy
# Unable to get Laiminga diena from Eglė Jurgaitytė
# local variable 'track_id' referenced before assignment missing Laiminga diena
# Unable to get Prati mi SMS  from Bobi Andonov
# local variable 'track_id' referenced before assignment missing Prati mi SMS
# Unable to get Gioupi gia!  from Elena Mannouri and Charis Savva
# local variable 'track_id' referenced before assignment missing Gioupi gia!
# Unable to get Forever from Karakat Bashanova
# local variable 'track_id' referenced before assignment missing Forever
# Unable to get Chasing Sunsets from Chanel Monseigneur
# local variable 'track_id' referenced before assignment missing Chasing Sunsets
# Unable to get Ill Be Standing from Ala Tracz
# local variable 'track_id' referenced before assignment missing Ill Be Standing
# Unable to get Heartbeat from Petar Aničić
# local variable 'track_id' referenced before assignment missing Heartbeat
# Unable to get Du from Mimmi Sandén
# local variable 'track_id' referenced before assignment missing Du
# Unable to get Malenkiy prints  from Ekaterina Ryabova
# local variable 'track_id' referenced before assignment missing Malenkiy prints
# Unable to get Barcelona  from Luara Hayrapetyan
# local variable 'track_id' referenced before assignment missing Barcelona
# Unable to get Ai puterea în mâna ta from Ioana Anuța
# local variable 'track_id' referenced before assignment missing Ai puterea în mâna ta
# Unable to get Onaj pravi  from Ništa Lično
# local variable 'track_id' referenced before assignment missing Onaj pravi
# Unable to get Lurji prinveli  from Princesses
# local variable 'track_id' referenced before assignment missing Lurji prinveli
# Unable to get Click Clack from Ralf Mackenbach
# local variable 'track_id' referenced before assignment missing Click Clack
# Unable to get Thalassa, helios, aeras, fotia  from Rafaella Costa
# local variable 'track_id' referenced before assignment missing Thalassa, helios, aeras, fotia
# Unable to get Double Trouble from Francesca & Mikaela
# local variable 'track_id' referenced before assignment missing Double Trouble
# Unable to get Try topoli, try surmy  from Andranik Alexanyan
# local variable 'track_id' referenced before assignment missing Try topoli, try surmy
# Unable to get Zo verliefd  from Laura Omloop
# local variable 'track_id' referenced before assignment missing Zo verliefd
# Unable to get Volshebniy krolik  from Yury Demidovich
# local variable 'track_id' referenced before assignment missing Volshebniy krolik
# Unable to get Za ljubovta from Sara Markoska
# local variable 'track_id' referenced before assignment missing Za ljubovta
# Unable to get qalma eurovision from Yerzhan Maksim
# local variable 'track_id' referenced before assignment missing qalma eurovision
# Unable to get Colours of Your Dream eurovision from Karina
# local variable 'track_id' referenced before assignment missing Colours of Your Dream eurovision
# Unable to get Lenina pesma  from Lena Stamenković
# local variable 'track_id' referenced before assignment missing Lenina pesma
# Unable to get Gabede  from The Virus
# local variable 'track_id' referenced before assignment missing Gabede
# Unable to get Prva ljubezen from Lina Kuduzović
# local variable 'track_id' referenced before assignment missing Prva ljubezen
# Unable to get Mechta   from Mikhail Smirnov
# local variable 'track_id' referenced before assignment missing Mechta
# Unable to get Pletenka – Braid of Love  from Ivana Petkovska & Magdalena Aleksovska
# local variable 'track_id' referenced before assignment missing Pletenka – Braid of Love
# Unable to get Volshebstvo   from Ruslan Aslanov
# local variable 'track_id' referenced before assignment missing Volshebstvo
# Unable to get Pochny z sebe - Start with Yourself  from Anna Trincher
# local variable 'track_id' referenced before assignment missing Pochny z sebe - Start with Yourself
# Unable to get Colour of Hope from Gabriela Yordanova & Ivan Stoyanov
# local variable 'track_id' referenced before assignment missing Colour of Hope
# Unable to get Mirror from Kamilla Ismailova
# local variable 'track_id' referenced before assignment missing Mirror
# Unable to get Not My Soul from Destiny Chukunyere
# local variable 'track_id' referenced before assignment missing Not My Soul
# Unable to get Dambaje from Mishela Rapo
# local variable 'track_id' referenced before assignment missing Dambaje
# Unable to get Oluja from Jana Mirković
# local variable 'track_id' referenced before assignment missing Oluja
# Unable to get Sokal  from Nadezhda Misyakova
# local variable 'track_id' referenced before assignment missing Sokal
# Unable to get Planet of the Children from Krisia, Hasan & Ibrahim
# local variable 'track_id' referenced before assignment missing Planet of the Children
# Unable to get Breaking My Heart from The Peppermints
# local variable 'track_id' referenced before assignment missing Breaking My Heart
# Unable to get Game Over from Josie
# local variable 'track_id' referenced before assignment missing Game Over
# Unable to get Happy Day from Lizi Pop
# local variable 'track_id' referenced before assignment missing Happy Day
# Unable to get Spring Will Come from Sympho-Nick
# local variable 'track_id' referenced before assignment missing Spring Will Come
# Unable to get Nisi sam  from Ula Ložar
# local variable 'track_id' referenced before assignment missing Nisi sam
# Unable to get Budi dijete na jedan dan from Maša Vujadinović & Lejla Vulić
# local variable 'track_id' referenced before assignment missing Budi dijete na jedan dan
# Unable to get Tu primo grande amore from Vincenzo Cantiello
# local variable 'track_id' referenced before assignment missing Tu primo grande amore
# Unable to get People of the Sun from Betty
# local variable 'track_id' referenced before assignment missing People of the Sun
# Unable to get Dreamer from Alisa Kozhikina
# local variable 'track_id' referenced before assignment missing Dreamer
# Unable to get Svet u mojim očima  from Emilija Đonin
# local variable 'track_id' referenced before assignment missing Svet u mojim očima
# Unable to get Diamonds from Federica Falzon
# local variable 'track_id' referenced before assignment missing Diamonds
# Unable to get Around from Julia van Bergen
# local variable 'track_id' referenced before assignment missing Around
# Unable to get Love Will Lead Our Way from Martija Stanojković
# local variable 'track_id' referenced before assignment missing Love Will Lead Our Way
# Unable to get Musyka moikh pobed from Alexander Minyonok
# local variable 'track_id' referenced before assignment missing Musyka moikh pobed
# Unable to get Cara Mamma - Dear Mom from Fiamma Boccia
# local variable 'track_id' referenced before assignment missing Cara Mamma - Dear Mom
# Unable to get Fili gia panta from Nicolas Ganopoulos
# local variable 'track_id' referenced before assignment missing Fili gia panta
# Unable to get Mia efhi from Theodora Rafti
# local variable 'track_id' referenced before assignment missing Mia efhi
# Unable to get Tantsuy from Volha Satsiuk
# local variable 'track_id' referenced before assignment missing Tantsuy
# Unable to get Ti ne me poznavaš  from Marija & Viktorija
# local variable 'track_id' referenced before assignment missing Ti ne me poznavaš
# Unable to get Coś mnie nosi from Katarzyna Żurawik
# local variable 'track_id' referenced before assignment missing Coś mnie nosi
# Unable to get Sinnsykt gal forelsket from 2U
# local variable 'track_id' referenced before assignment missing Sinnsykt gal forelsket
# Unable to get Tobele sunt viața mea from Bubu
# local variable 'track_id' referenced before assignment missing Tobele sunt viața mea
# Unable to get De vriendschapsband from X!NK
# local variable 'track_id' referenced before assignment missing De vriendschapsband
# Unable to get My Song for the World from Tom Morley
# local variable 'track_id' referenced before assignment missing My Song for the World
# Unable to get Stoppa mig from The Honeypies
# local variable 'track_id' referenced before assignment missing Stoppa mig
# Unable to get Like a Star from Sarah Harrison
# local variable 'track_id' referenced before assignment missing Like a Star
# Unable to get Mijn ogen zeggen alles from Roel Felius
# local variable 'track_id' referenced before assignment missing Mijn ogen zeggen alles
# Unable to get I Wanna Be A Star from Nicole Nicolaou
# local variable 'track_id' referenced before assignment missing I Wanna Be A Star
# Unable to get Mój Dom from Alicja Rega
# local variable 'track_id' referenced before assignment missing Mój Dom
# Unable to get Youtuber from Mariana Venâncio
# local variable 'track_id' referenced before assignment missing Youtuber
# Unable to get Suile Glasa from Muireann McDonnell
# local variable 'track_id' referenced before assignment missing Suile Glasa
# Unable to get Dancing Through Life from Mina Blažev
# local variable 'track_id' referenced before assignment missing Dancing Through Life
# Unable to get Voice of the Heart from Grigol Kipshidze
# local variable 'track_id' referenced before assignment missing Voice of the Heart
# Unable to get Don't Touch My Tree from Ana Kodra
# local variable 'track_id' referenced before assignment missing Don't Touch My Tree
# Unable to get Don't Stop from Anastasiya Baginska
# local variable 'track_id' referenced before assignment missing Don't Stop
# Unable to get Dawra Tond from Gianluca Cilia
# local variable 'track_id' referenced before assignment missing Dawra Tond
# Unable to get Wings from Polina Bogusevich
# local variable 'track_id' referenced before assignment missing Wings
# Unable to get Ceo svet je naš from Irina Brodić & Jana Paunović
# local variable 'track_id' referenced before assignment missing Ceo svet je naš
# Unable to get Scelgo (My Choice) from Maria Iside Fiore
# local variable 'track_id' referenced before assignment missing Scelgo (My Choice)
# Unable to get Me and My Guitar from Rustam Karimov
# local variable 'track_id' referenced before assignment missing Me and My Guitar
# Unable to get Choco Factory from Monica Avanesyan
# local variable 'track_id' referenced before assignment missing Choco Factory
# Unable to get O-o-O Sole intorno a me from Michele Perniola
# local variable 'track_id' referenced before assignment missing O-o-O Sole intorno a me
# Unable to get Ohrid i muzika  from Barbara Popović
# local variable 'track_id' referenced before assignment missing Ohrid i muzika
# Unable to get We Are One from Sofia Tarasova
# local variable 'track_id' referenced before assignment missing We Are One
# Unable to get Poy so mnoy  from Ilya Volkov
# local variable 'track_id' referenced before assignment missing Poy so mnoy
# Unable to get Cum să fim from Rafael Bobeica
# local variable 'track_id' referenced before assignment missing Cum să fim
# Unable to get Give Me Your Smile from The Smile Shop
# local variable 'track_id' referenced before assignment missing Give Me Your Smile
# Unable to get The Start from Gaia Cauchi
# local variable 'track_id' referenced before assignment missing The Start
# Unable to get Dream On from Dayana Kirillova
# local variable 'track_id' referenced before assignment missing Dream On
# Unable to get Odelia Ranuni  from Mariam Romelashvili
# local variable 'track_id' referenced before assignment missing Odelia Ranuni
# Unable to get Erazanq  from Arevik
# local variable 'track_id' referenced before assignment missing Erazanq
# Unable to get I mousiki dinei ftera from Yiorgos Ioannides
# local variable 'track_id' referenced before assignment missing I mousiki dinei ftera
# Unable to get Só quero é cantar from Jorge Leiria
# local variable 'track_id' referenced before assignment missing Só quero é cantar
# Unable to get Otlichnitsa  from Alexandra Golovchenko
# local variable 'track_id' referenced before assignment missing Otlichnitsa
# Unable to get Sha-la-la from 4Kids
# local variable 'track_id' referenced before assignment missing Sha-la-la
# Unable to get Bonbolandiya from Bon-Bon
# local variable 'track_id' referenced before assignment missing Bonbolandiya
# Unable to get Piši mi  from Nevena Božović
# local variable 'track_id' referenced before assignment missing Piši mi
# Unable to get Adem in, adem uit from Lisa, Amy & Shelley
# local variable 'track_id' referenced before assignment missing Adem in, adem uit
# Unable to get Ding Ding Dong  from Rosica Kulakova and Dimitar Stojmenovski
# local variable 'track_id' referenced before assignment missing Ding Ding Dong
# Unable to get Urok hlamuru from Ilona Halytska
# local variable 'track_id' referenced before assignment missing Urok hlamuru
# Unable to get Nu eller aldrig from Frida Sandén
# local variable 'track_id' referenced before assignment missing Nu eller aldrig
# Unable to get Kapou berdeftika  from Made in Greece
# local variable 'track_id' referenced before assignment missing Kapou berdeftika
# Unable to get Kai miestas snaudžia from Lina Joy
# local variable 'track_id' referenced before assignment missing Kai miestas snaudžia
# Unable to get S druz'yami  from Alexey Zhigalkovich
# local variable 'track_id' referenced before assignment missing S druz'yami
# Unable to get Agoria koritsia  from Luis Panagiotou & Christina Christofi
# local variable 'track_id' referenced before assignment missing Agoria koritsia
# Unable to get Goed from Kimberly Nieuwenhuis
# local variable 'track_id' referenced before assignment missing Goed
# Unable to get Povestea mea from New Star Music
# local variable 'track_id' referenced before assignment missing Povestea mea
# Unable to get Khlopchyk Rock 'n' Roll  from Nazar Slyusarchuk
# local variable 'track_id' referenced before assignment missing Khlopchyk Rock 'n' Roll
# Unable to get Te doy mi voz from Dani Fernández
# local variable 'track_id' referenced before assignment missing Te doy mi voz
# Unable to get Učimo strane jezike  from Neustrašivi učitelji stranih jezika [sr]
# local variable 'track_id' referenced before assignment missing Učimo strane jezike
# Unable to get Extra Cute from Sophie Debattista
# local variable 'track_id' referenced before assignment missing Extra Cute
# Unable to get Vljubena  from Zana Aliu
# local variable 'track_id' referenced before assignment missing Vljubena
# Unable to get Den peirazei  from Chloe Sofia Boleti
# local variable 'track_id' referenced before assignment missing Den peirazei
# Unable to get Noviy den  from Andrey Kunets
# local variable 'track_id' referenced before assignment missing Noviy den
# Unable to get Een tocht door het donker from Thor!
# local variable 'track_id' referenced before assignment missing Een tocht door het donker
# Unable to get Lea from Mateo Đido
# local variable 'track_id' referenced before assignment missing Lea
# Unable to get Vesenniy Jazz from Tolmachevy Twins
# local variable 'track_id' referenced before assignment missing Vesenniy Jazz
# Unable to get A more-more  from Egor Zheshko
# local variable 'track_id' referenced before assignment missing A more-more
# Unable to get Mitt mod from Lova Sönnerbo
# local variable 'track_id' referenced before assignment missing Mitt mod
# Unable to get Girls and Boys  from Omar and Suada
# local variable 'track_id' referenced before assignment missing Girls and Boys
# Unable to get Abracadabra from Fabian
# local variable 'track_id' referenced before assignment missing Abracadabra
# Unable to get Let the Music Win from Kids.il
# local variable 'track_id' referenced before assignment missing Let the Music Win
# Unable to get Kam një këngë vetëm për ju from Igzidora Gjeta
# local variable 'track_id' referenced before assignment missing Kam një këngë vetëm për ju
# Unable to get Sweetie Baby from Compass Band
# local variable 'track_id' referenced before assignment missing Sweetie Baby
# Unable to get Nebo  from Anastasiya Petryk
# local variable 'track_id' referenced before assignment missing Nebo
# Unable to get Funky Lemonade from Funkids
# local variable 'track_id' referenced before assignment missing Funky Lemonade
# Unable to get Toate vor fi from Denis Midone
# local variable 'track_id' referenced before assignment missing Toate vor fi
# Unable to get Power of a Song from Young Talent Team
# local variable 'track_id' referenced before assignment missing Power of a Song
# Unable to get Hij is een kei from Klaartje & Nicky
# local variable 'track_id' referenced before assignment missing Hij is een kei
# Unable to get Birichino from Demis Mirarchi
# local variable 'track_id' referenced before assignment missing Birichino
# Unable to get En stjerne skal jeg bli from @lek
# local variable 'track_id' referenced before assignment missing En stjerne skal jeg bli
# Unable to get Si on voulait bien from Thomas Pontier
# local variable 'track_id' referenced before assignment missing Si on voulait bien
# Unable to get Zabava  from Martina Siljanovska
# local variable 'track_id' referenced before assignment missing Zabava
# Unable to get Łap życie from KWADro
# local variable 'track_id' referenced before assignment missing Łap życie
# Unable to get Onira  from Marios Tofi
# local variable 'track_id' referenced before assignment missing Onira
# Unable to get Spiavajcie so mnoj from Egor Volchek
# local variable 'track_id' referenced before assignment missing Spiavajcie so mnoj
# Unable to get Balts vai melns from Mārtiņš Tālbergs and C-Stones Juniors
# local variable 'track_id' referenced before assignment missing Balts vai melns
# Unable to get The Best Is Yet to Come from Cory Spedding
# local variable 'track_id' referenced before assignment missing The Best Is Yet to Come
# Unable to get Pigen er min from Cool Kids
# local variable 'track_id' referenced before assignment missing Pigen er min
# Unable to get Varför jag? from Limelights
# local variable 'track_id' referenced before assignment missing Varför jag?
# Unable to get Accroche-toi from Free Spirits
# local variable 'track_id' referenced before assignment missing Accroche-toi
# Unable to get Îți mulțumesc from Noni Răzvan Ene
# local variable 'track_id' referenced before assignment missing Îți mulțumesc
# Unable to get Ali Baba from Ștefan Roșcovan
# local variable 'track_id' referenced before assignment missing Ali Baba
# Unable to get Čarobna noć  from Sonja Škorić
# local variable 'track_id' referenced before assignment missing Čarobna noć
# Unable to get Miy litak  from Yulia Gurska
# local variable 'track_id' referenced before assignment missing Miy litak
# Unable to get Allt jag vill ha from Josefine Ridell
# local variable 'track_id' referenced before assignment missing Allt jag vill ha
# Unable to get Boy and Girl from Sasha Lazin and Liza Drozd
# local variable 'track_id' referenced before assignment missing Boy and Girl
# Unable to get Viva la Dance  from Šarlote Lēnmane
# local variable 'track_id' referenced before assignment missing Viva la Dance
# Unable to get Get Up! from Jill and Lauren
# local variable 'track_id' referenced before assignment missing Get Up!
# Unable to get Knock Knock!....Boom! Boom! from Nicole Azzopardi
# local variable 'track_id' referenced before assignment missing Knock Knock!....Boom! Boom!
# Unable to get Muzyki svet  from Daniil Kozlov
# local variable 'track_id' referenced before assignment missing Muzyki svet
# Unable to get Mari Dari from Mariam Kakhelishvili
# local variable 'track_id' referenced before assignment missing Mari Dari
# Unable to get Еооо, Еооо from Anja Veterova
# local variable 'track_id' referenced before assignment missing Еооо, Еооо
# Unable to get Romeo & Juliet from Katya Ryabova
# local variable 'track_id' referenced before assignment missing Romeo & Juliet
# Unable to get Moondog from Amanda Bašmakova
# local variable 'track_id' referenced before assignment missing Moondog
# Unable to get No, No from Lerika
# local variable 'track_id' referenced before assignment missing No, No
# Unable to get Welcome to Armenia from Dalita
# local variable 'track_id' referenced before assignment missing Welcome to Armenia
# Unable to get Superhero from Ivan Ivanov
# local variable 'track_id' referenced before assignment missing Superhero
# Unable to get Debesys from Paulina Skrabytė
# local variable 'track_id' referenced before assignment missing Debesys
# Unable to get Evropa  from Kristall
# local variable 'track_id' referenced before assignment missing Evropa
# Unable to get Žimi ovoj frak  from Dorijan Dlaka
# local variable 'track_id' referenced before assignment missing Žimi ovoj frak
# Unable to get Angely dobra  from Lidiya Zablotskaya
# local variable 'track_id' referenced before assignment missing Angely dobra
# Unable to get Een kusje meer from Femke
# local variable 'track_id' referenced before assignment missing Een kusje meer
# Unable to get Tora einai i seira mas from Alexandros & Kalli
# local variable 'track_id' referenced before assignment missing Tora einai i seira mas
# Unable to get Rock Baby from Lorena Jelusić
# local variable 'track_id' referenced before assignment missing Rock Baby
# Unable to get Țurai! from Alina Eremia
# local variable 'track_id' referenced before assignment missing Țurai!
# Unable to get How Does It Feel? from Joni Fuller
# local variable 'track_id' referenced before assignment missing How Does It Feel?
# Unable to get Gränslös kärlek from M+
# local variable 'track_id' referenced before assignment missing Gränslös kärlek
# Unable to get Doroga k solntsu from Vladislav Krutskikh and Street Magic
# local variable 'track_id' referenced before assignment missing Doroga k solntsu
# Unable to get Rodendeski baknež from Denis Dimoski
# local variable 'track_id' referenced before assignment missing Rodendeski baknež
# Unable to get Ljubav pa fudbal from Filip Vučić
# local variable 'track_id' referenced before assignment missing Ljubav pa fudbal
# Unable to get Es esmu maza jauka meitene from Kids4Rock
# local variable 'track_id' referenced before assignment missing Es esmu maza jauka meitene
# Unable to get Mes rêves from Lindsay
# local variable 'track_id' referenced before assignment missing Mes rêves
# Unable to get Make It Right! from Thea and Friends
# local variable 'track_id' referenced before assignment missing Make It Right!
# Unable to get Sommer og skolefri[a] from Malin
# local variable 'track_id' referenced before assignment missing Sommer og skolefri[a]
# Unable to get Te traigo flores from Antonio José
# local variable 'track_id' referenced before assignment missing Te traigo flores
# Unable to get My vmeste  from Ksenia Sitnik
# local variable 'track_id' referenced before assignment missing My vmeste

# %%
train=pd.concat(lista)
train.to_csv("training.csv",index=False)
train
# Out:
#       duration  key  loudness  mode    tempo  artist_hotttnesss  \
# 9    164.78517    0    -3.892     0  173.703               0.03
# 15   181.99773    7    -9.342     0   95.001               0.23
# 16   179.98036    0    -3.938     1  113.932               0.26
# 17   182.60023    2    -7.322     1  113.981               0.17
# 20   173.16830    6    -6.834     1  101.021               0.35
# ..         ...  ...       ...   ...      ...                ...
# 255  168.04000    2    -6.348     0  134.025               0.33
# 257  320.30110    8    -3.767     1  130.034               0.33
# 258  214.00000    4   -15.249     1  136.034               0.01
# 261  142.53333    8    -9.105     1   90.247               0.32
# 268  167.45332    6    -4.085     1  112.028               0.33
#
#      end_of_fade_in  start_of_fade_out  mode_confidence  key_confidence  ...  \
# 9           0.00000          164.78517            0.487           0.308  ...
# 15          0.00000          178.39311            0.873           0.876  ...
# 16          0.00000          173.35439            0.636           0.742  ...
# 17          0.24989          176.25687            0.687           0.619  ...
# 20          0.15116          168.11247            0.768           0.742  ...
# ..              ...                ...              ...             ...  ...
# 255         0.36594          163.22467            0.427           0.266  ...
# 257         0.00000          316.44736            0.513           0.466  ...
# 258         0.00000          211.68472            0.387           0.501  ...
# 261         0.00000          138.80309            0.602           0.578  ...
# 268         0.10730          163.57297            0.556           0.686  ...
#
#      danceability  energy speechiness  acousticness  instrumentalness  \
# 9           0.453   0.888      0.0634       0.09830          0.000000
# 15          0.565   0.563      0.0296       0.13100          0.000002
# 16          0.758   0.647      0.0419       0.43300          0.000000
# 17          0.667   0.405      0.0292       0.54700          0.000000
# 20          0.611   0.623      0.0367       0.05690          0.000045
# ..            ...     ...         ...           ...               ...
# 255         0.775   0.683      0.0480       0.07720          0.000000
# 257         0.655   0.989      0.0494       0.03720          0.018000
# 258         0.839   0.707      0.0666       0.00116          0.918000
# 261         0.616   0.893      0.0812       0.07460          0.000078
# 268         0.688   0.688      0.0268       0.44500          0.000000
#
#      liveness  valence  duration_ms  Points       Country
# 9      0.4110    0.812       164785   100.0         Malta
# 15     0.2530    0.114       181998     NaN       Belarus
# 16     0.1720    0.597       179980     NaN        France
# 17     0.1920    0.329       182600     NaN       Germany
# 20     0.0930    0.428       173168     NaN   Netherlands
# ..        ...      ...          ...     ...           ...
# 255    0.3530    0.580       168040   103.0   Netherlands
# 257    0.5930    0.761       320301    57.0        Sweden
# 258    0.1690    0.965       214000   108.0       Georgia
# 261    0.0786    0.890       142533   121.0       Denmark
# 268    0.3060    0.687       167453    82.0   Netherlands
#
# [92 rows x 24 columns]

# %% [markdown]
# ## Ahora importaremos el CSV con la información de los participantes del 2020 (sin puntuación ya que el evento todavía no ha ocurrido, esto es lo que nos gustaría predecir).

# %%
df_2020=pd.read_csv("2020.csv")

# %%
lista2=[]
for index, row in df_2020.iterrows():
    try:
        dic = get_info(song_name=row["Song"],artist_name=row["Artist"],force=True)
        dic['Country']=row['Country']
        lista2.append(pd.DataFrame(dic,index=[index]))
        
    except Exception as e:
        print(e,f"missing {row['Artist'],row['Song']}")
# Out:
# Unable to get Forever from Karakat Bashanova
# Trying Forever by only artist Karakat Bashanova
# list index out of range missing ('Karakat Bashanova', 'Forever')
# Unable to get Chasing Sunsets from Chanel Monseigneur
# Trying Chasing Sunsets by only artist Chanel Monseigneur
# list index out of range missing ('Chanel Monseigneur', 'Chasing Sunsets')
# Unable to get Ill Be Standing from Ala Tracz
# Trying Ill Be Standing by only artist Ala Tracz
# Unable to get Heartbeat from Petar Aničić
# Trying Heartbeat by only artist Petar Aničić
# list index out of range missing ('Petar Aničić', 'Heartbeat')

# %% [markdown]
# ### Finalmente terminamos con nuestro conjunto del año 2020 enriquecido por las APIs de Spotify (sin la columna de puntuación)

# %%
final=pd.concat(lista2)
pd.set_option('display.max_columns', 500)
final.to_csv('final.csv',index=False)
final
# Out:
#      duration  key  loudness  mode    tempo  artist_hotttnesss  \
# 0   181.99773    7    -9.342     0   95.001               0.23
# 1   179.98036    0    -3.938     1  113.932               0.26
# 2   182.60023    2    -7.322     1  113.981               0.17
# 5   173.16830    6    -6.834     1  101.021               0.35
# 6   180.54675    0    -2.799     1  122.028               0.31
# 7   177.33333    8    -6.671     1  180.020               0.14
# 9   167.98611    6    -6.184     0  100.040               0.30
# 10  157.90765   11    -7.370     0  153.369               0.19
#
#     end_of_fade_in  start_of_fade_out  mode_confidence  key_confidence  \
# 0          0.00000          178.39311            0.873           0.876
# 1          0.00000          173.35439            0.636           0.742
# 2          0.24989          176.25687            0.687           0.619
# 5          0.15116          168.11247            0.768           0.742
# 6          0.00000          173.85940            0.490           0.546
# 7          0.00000          169.28508            0.311           0.507
# 9          2.61805          162.60934            0.379           0.062
# 10         0.53991          152.74086            0.655           0.696
#
#     time_signature  time_signature_confidence  year  popularity  danceability  \
# 0                4                      0.941  2020          35         0.565
# 1                4                      1.000  2020          38         0.758
# 2                4                      0.783  2020          28         0.667
# 5                4                      1.000  2020          46         0.611
# 6                4                      0.899  2020          42         0.523
# 7                4                      1.000  2020          26         0.258
# 9                4                      1.000  2020          42         0.744
# 10               4                      0.973  2020          31         0.359
#
#     energy  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    0.563       0.0296        0.1310          0.000002    0.2530    0.114
# 1    0.647       0.0419        0.4330          0.000000    0.1720    0.597
# 2    0.405       0.0292        0.5470          0.000000    0.1920    0.329
# 5    0.623       0.0367        0.0569          0.000045    0.0930    0.428
# 6    0.851       0.0373        0.0148          0.000001    0.2920    0.181
# 7    0.499       0.0377        0.4550          0.000000    0.0773    0.428
# 9    0.574       0.1670        0.0555          0.000000    0.0817    0.353
# 10   0.497       0.0439        0.4360          0.000000    0.0787    0.328
#
#     duration_ms       Country
# 0        181998       Belarus
# 1        179980        France
# 2        182600       Germany
# 5        173168   Netherlands
# 6        180547        Poland
# 7        177333        Russia
# 9        167986         Spain
# 10       157908       Ukraine
